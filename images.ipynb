# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# create images folder
os.makedirs("images", exist_ok=True)

# create 5 dummy images
for i in range(5):
    img = np.random.rand(150,150,3)  # random image
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Sample {i+1}")
    plt.savefig(f"images/sample_{i+1}.png")
    plt.close()

print("✅ Images created!")
# Out:
# ✅ Images created!

# %%
images/
   sample_1.png
   sample_2.png
   sample_3.png
   sample_4.png
   sample_5.png
